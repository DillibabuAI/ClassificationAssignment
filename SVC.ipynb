# %%
#Get the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load the dataset
dataset = pd.read_csv("CKD.csv")

# %%
#display dataset
dataset
# Out:
#      age         bp sg  al  su     rbc        pc         pcc          ba  \
# 0      2  76.459948  c   3   0  normal  abnormal  notpresent  notpresent
# 1      3  76.459948  c   2   0  normal    normal  notpresent  notpresent
# 2      4  76.459948  a   1   0  normal    normal  notpresent  notpresent
# 3      5  76.459948  d   1   0  normal    normal  notpresent  notpresent
# 4      5  50.000000  c   0   0  normal    normal  notpresent  notpresent
# ..   ...        ... ..  ..  ..     ...       ...         ...         ...
# 394   51  70.000000  a   0   0  normal    normal  notpresent  notpresent
# 395   51  70.000000  c   0   2  normal    normal  notpresent  notpresent
# 396   51  70.000000  c   3   0  normal    normal  notpresent  notpresent
# 397   51  90.000000  a   0   0  normal    normal  notpresent  notpresent
# 398   51  80.000000  a   0   0  normal    normal  notpresent  notpresent
#
#             bgr  ...        pcv            wc        rc  htn   dm  cad  appet  \
# ...

# %%
#remove dummies using preprocessing method
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
#display data post removal of dummies
dataset
# Out:
#      age         bp  al  su         bgr          bu        sc         sod  \
# 0      2  76.459948   3   0  148.112676   57.482105  3.077356  137.528754
# 1      3  76.459948   2   0  148.112676   22.000000  0.700000  137.528754
# 2      4  76.459948   1   0   99.000000   23.000000  0.600000  138.000000
# 3      5  76.459948   1   0  148.112676   16.000000  0.700000  138.000000
# 4      5  50.000000   0   0  148.112676   25.000000  0.600000  137.528754
# ..   ...        ...  ..  ..         ...         ...       ...         ...
# 394   51  70.000000   0   0  219.000000   36.000000  1.300000  139.000000
# 395   51  70.000000   0   2  220.000000   68.000000  2.800000  137.528754
# 396   51  70.000000   3   0  110.000000  115.000000  6.000000  134.000000
# 397   51  90.000000   0   0  207.000000   80.000000  6.800000  142.000000
# 398   51  80.000000   0   0  100.000000   49.000000  1.000000  140.000000
#
#           pot       hrmo  ...  pc_normal  pcc_present  ba_present  htn_yes  \
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset['classification_yes']

# %%
indep.shape
# Out:
# (399, 27)

# %%
dep.shape
# Out:
# (399,)

# %%
#Split into training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
param_grid = {'kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'], 'gamma' : ['scale', 'auto'], 'C': [1.0, 2.0, 3.5, 4.7, 5.8]}
classifier = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
#fitting the model for grid search
classifier.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END .C=1.0, gamma=scale, kernel=linear;, score=0.963 total time=  22.6s
# [CV 2/5] END .C=1.0, gamma=scale, kernel=linear;, score=0.943 total time=   2.2s
# [CV 3/5] END .C=1.0, gamma=scale, kernel=linear;, score=0.925 total time=   5.7s
# [CV 4/5] END .C=1.0, gamma=scale, kernel=linear;, score=0.943 total time=   7.4s
# [CV 5/5] END .C=1.0, gamma=scale, kernel=linear;, score=0.962 total time=   8.6s
# [CV 1/5] END ...C=1.0, gamma=scale, kernel=poly;, score=0.630 total time=   0.0s
# [CV 2/5] END ...C=1.0, gamma=scale, kernel=poly;, score=0.642 total time=   0.0s
# [CV 3/5] END ...C=1.0, gamma=scale, kernel=poly;, score=0.623 total time=   0.0s
# [CV 4/5] END ...C=1.0, gamma=scale, kernel=poly;, score=0.623 total time=   0.0s
# [CV 5/5] END ...C=1.0, gamma=scale, kernel=poly;, score=0.623 total time=   0.0s
# [CV 1/5] END ....C=1.0, gamma=scale, kernel=rbf;, score=0.630 total time=   0.0s
# ...
